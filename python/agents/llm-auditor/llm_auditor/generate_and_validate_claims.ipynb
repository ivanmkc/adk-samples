# %%
import os

path = "/Users/ivanmkc/code/adk-samples/output/companies/blue_ridge_outfitters/run_0/Blue Ridge Outfitters_ _Gear Up for Your Adventure..md"
with open(path, "r") as f:
    text = f.read()

# %%
len(text.split("\n"))

# %%
len(text)

# %%
import dspy
import mlflow
mlflow.dspy.autolog()
mlflow.set_experiment("extract_claims")

model_name = "gemini/gemini-2.5-pro-preview-03-25"
# model_name = "gemini/gemini-2.0-flash"
lm = dspy.LM(
    model=model_name,
    # max_tokens=65535,
    # allowed_openai_params=["thinking"],
    # thinking={"type": "enabled", "budget_tokens": 1024},
)
dspy.configure(lm=lm)

# %%
from typing import List, Optional, Iterator
import dspy
from pydantic import BaseModel, Field
import asyncio
from tqdm.asyncio import tqdm

# --- DSPy Signature for Claim Extraction ---
class ClaimExtractionSignature(dspy.Signature):
    """
    Given a source text, extract verifiable claims.
    Ensure each quote is supported by the source text.
    Aim to extract distinct and significant claims.
    Avoid claims that include ambiguity or speculation.
    """

    source_text: str = dspy.InputField(
        desc="The full text from which to extract claims."
    )
    extracted_claims: List[str] = dspy.OutputField(
        desc="A list of extracted claims. Each claim needs to be self-contained such that context-dependent words/pronouns (e.g. this, that, it, etc) without explicit noun phrases need to be replaced with the thing/concept they refer to."
    )


def batch_text(text: str, batch_size: int) -> Iterator[str]:
    batch = []
    
    for line in text.split("\n"):
        batch.append(line)

        if len(batch) >= batch_size:
            yield "\n".join(batch)
            batch = []
    
    if batch:
        yield batch

# --- DSPy Module for Verifiable Claim Extraction ---
class VerifiableClaimExtractor(dspy.Module):
    def __init__(self):
        super().__init__()
        self.claim_extractor = dspy.ChainOfThought(ClaimExtractionSignature)

    async def forward(self, source_text: str) -> dspy.Prediction:
        """
        Extracts verifiable claims from the given source text.

        Args:
            source_text: The text to extract claims from.

        Returns:
            A dspy.Prediction object containing a list of extracted claims.
        """

        semaphore = asyncio.Semaphore(5)
        claim_extractor_async = dspy.asyncify(self.claim_extractor)
        async def extract_claims(text: str) -> list[str]:
            async with semaphore:
                return await claim_extractor_async(source_text=text)
        
        extraction_tasks = [extract_claims(batch)
                            for batch in batch_text(source_text, batch_size=4)
                            ]
        
        predictions = await tqdm.gather(*extraction_tasks) 
        claims = [claim
                        for prediction in predictions
                        for claim in prediction.extracted_claims
                       ]

        return claims

# %%
# for batch in batch_text(text, 10):
#     print(batch)
#     print("---------")

# %%
import dspy
# lm = dspy.LM(model="gemini/gemini-2.5-pro-preview-03-25")
lm = dspy.LM(
    model="gemini/gemini-2.5-pro-preview-03-25",
    max_tokens=65535,
    allowed_openai_params=['thinking'], 
    thinking={"type": "enabled", "budget_tokens": 2048},
)
dspy.configure(lm=lm)

# %%
claim_extractor_module = VerifiableClaimExtractor()

extracted_claims = await claim_extractor_module.forward(
    source_text=text,
)

# %%
extracted_claims

# %%
# extractor = dspy.ChainOfThought(ClaimExtractionSignature)
# extractor_async = dspy.asyncify(extractor)
# prediction = await extractor_async(source_text="Hello world.")

# %%
# prediction.extracted_claims

# %%
class FalseClaimSignature(dspy.Signature):
    """
    Given a source text, make up falsehoods that contradict the text.
    Ensure each quote is contradicted by the source text.
    Aim to create distinct and significant fake claims.
    Avoid claims that include ambiguity or speculation.
    """

    source_text: str = dspy.InputField(
        desc="The full text from which to extract claims."
    )
    false_claims: List[str] = dspy.OutputField(
        desc="A list of false claims. Each claim needs to be self-contained such that context-dependent words/pronouns (e.g. this, that, it, etc) without explicit noun phrases need to be replaced with the thing/concept they refer to."
    )


def batch_text(text: str, batch_size: int) -> Iterator[str]:
    batch = []
    
    for line in text.split("\n"):
        batch.append(line)

        if len(batch) >= batch_size:
            yield "\n".join(batch)
            batch = []
    
    if batch:
        yield batch

# --- DSPy Module for Verifiable Claim Extraction ---
class FalsehoodExtractor(dspy.Module):
    def __init__(self):
        super().__init__()
        self.claim_extractor = dspy.ChainOfThought(FalseClaimSignature)

    async def forward(self, source_text: str) -> dspy.Prediction:
        """
        Create incorrect information against the given source text.

        Args:
            source_text: The text to contradict.

        Returns:
            A dspy.Prediction object containing a list of 'false_claims'.
        """

        semaphore = asyncio.Semaphore(5)
        claim_extractor_async = dspy.asyncify(self.claim_extractor)
        async def extract_claims(text: str) -> list[str]:
            async with semaphore:
                return await claim_extractor_async(source_text=text)
        
        extraction_tasks = [extract_claims(batch)
                            for batch in batch_text(source_text, batch_size=4)
                            ]
        
        predictions = await tqdm.gather(*extraction_tasks) 
        claims = [claim
                        for prediction in predictions
                        for claim in prediction.false_claims
                       ]

        return claims

# %%
false_claim_generator_module = FalsehoodExtractor()

false_claims = await false_claim_generator_module.forward(
    source_text=text,
)

# %%
false_claims

# %%
class ClaimRewriterSignature(dspy.Signature):
    """
    Given a source text and an input claim:
    1. Analyze the claim. If it's underspecified (e.g., uses pronouns like 'it', 'this', 'they' without clear antecedents, or refers to concepts vaguely), rewrite it to be self-contained and unambiguous by incorporating necessary context from the source text.
    2. The rewritten claim MUST be clearly and unambiguously either be supported by or contradicted by the source text.
    3. Provide a verdict ('supported' or 'contradicted') for the rewritten claim against the source text.
    """

    source_text: str = dspy.InputField(
        desc="The source text for context and verification."
    )
    claim: str = dspy.InputField(
        desc="The input claim to analyze and rewrite."
    )
    rewritten_claim: str = dspy.OutputField(
        desc="The rewritten, self-contained, and unambiguous claim."
    )
    is_supported: bool = dspy.OutputField(
        # Restricting to these two as per the problem statement's emphasis
        desc="Verdict for the rewritten_claim: True if 'supported' and False if 'contradicted' by the source_text."
    )
    reasoning: str = dspy.OutputField(
        desc="Brief reasoning for the verdict and any significant rewrites made to achieve clarity and verifiability."
    )

class ClaimRewriter(dspy.Module):
    def __init__(self):
        super().__init__()
        # Using Predict as ChainOfThought might be overkill if the prompt is strong enough,
        # but CoT is generally more robust for complex reasoning.
        self.rewriter_predictor = dspy.ChainOfThought(ClaimRewriterSignature)

    async def forward(self, claim: str, source_text: str) -> dspy.Prediction:
        """
        Rewrites a claim for clarity and verifies if it's supported or contradicted by the source text.

        Args:
            claim: The claim string to process.
            source_text: The source text to use for context and verification.

        Returns:
            A dspy.Prediction object containing 'rewritten_claim', 'verdict', and 'reasoning'.
        """
        # dspy.Predict/ChainOfThought are not async by default.
        # We need to use dspy.asyncify for them if we want to await their calls.
        rewriter_predictor_async = dspy.asyncify(self.rewriter_predictor) # batch_size=1 as we process one claim at a time here
        
        # If source_text is very long, the LLM might struggle.
        # However, for claim rewriting/verification, the relevant source context is often local.
        # The current FalsehoodExtractor already batches source_text for generation,
        # so the source_text passed here will be a manageable chunk.
        prediction = await rewriter_predictor_async(claim=claim, source_text=source_text)
        return prediction

# %%
rewriter = ClaimRewriter()
all_claims = extracted_claims + false_claims
rewritten_predictions = await tqdm.gather(*[rewriter.forward(claim=claim, source_text=text) for claim in all_claims])

# %%
assert all([is_supported == prediction.is_supported for (is_supported, prediction) in zip([True for _ in range(len(extracted_claims))] + [False for _ in range(len(false_claims))], rewritten_predictions)]), "Pre and post rewriting is_supported are not consistent"

# %%
[prediction.rewritten_claim for prediction in rewritten_predictions]
# Out:
# [Prediction(
#      reasoning='The claim is a direct statement found in the first sentence of the source text. It is self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters has been equipping outdoor enthusiasts for their journeys for over half a century.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is directly supported by the first sentence of the source text, which states, "For over half a century, Blue Ridge Outfitters has been equipping outdoor enthusiasts for their journeys," and the second sentence, "Founded more than 50 years ago by the avid mountaineer Jedediah \'Jed\' Stone...". The original claim is already self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters was founded more than 50 years ago.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly verifiable from the source text. The first paragraph of the source text explicitly states that Blue Ridge Outfitters was "Founded more than 50 years ago by the avid mountaineer Jedediah \'Jed\' Stone".',
#      rewritten_claim="Blue Ridge Outfitters was founded by the avid mountaineer Jedediah 'Jed' Stone.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly verifiable from the source text. The first paragraph of the source text explicitly states, "Headquartered in the vibrant city of Asheville, North Carolina, Blue Ridge Outfitters continues its legacy...".',
#      rewritten_claim='Blue Ridge Outfitters is headquartered in Asheville, North Carolina.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and unambiguous. The source text explicitly states, "Blue Ridge Outfitters continues its legacy as a family-owned business, currently steered by the grandchildren of its founder." This directly supports the claim.',
#      rewritten_claim='Blue Ridge Outfitters is a family-owned business.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly verifiable from the source text. The first paragraph of the source text states, "Founded more than 50 years ago by the avid mountaineer Jedediah \'Jed\' Stone, the company has remained true to its roots... Blue Ridge Outfitters continues its legacy as a family-owned business, currently steered by the grandchildren of its founder." This directly supports the claim.',
#      rewritten_claim="Blue Ridge Outfitters is currently steered by the grandchildren of its founder, Jedediah 'Jed' Stone.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and unambiguous. The source text explicitly states in the "Operations and Reach" section: "While firmly rooted in Asheville, Blue Ridge Outfitters extends its reach across the country." Additionally, the introductory section mentions, "Headquartered in the vibrant city of Asheville, North Carolina, Blue Ridge Outfitters continues its legacy..." This directly supports the claim.',
#      rewritten_claim='Blue Ridge Outfitters is firmly rooted in Asheville, North Carolina.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is directly supported by the "Operations and Reach" section of the source text, which states, "While firmly rooted in Asheville, Blue Ridge Outfitters extends its reach across the country." The text further elaborates that this is achieved through a nationwide online store and retail locations in Colorado, Oregon, and Wyoming. The original claim is already self-contained and clear.',
#      rewritten_claim='Blue Ridge Outfitters extends its reach across the country.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is a direct statement found in the "Operations and Reach" section of the source text. It is clear, self-contained, and requires no rewriting.',
#      rewritten_claim='Blue Ridge Outfitters has a comprehensive online store catering to customers nationwide.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is specific and self-contained. The source text explicitly states under "Operations and Reach" that "the company operates prominent flagship retail locations in key outdoor hubs: Denver, Colorado; Bend, Oregon; and Jackson, Wyoming." This directly supports the claim.',
#      rewritten_claim='Blue Ridge Outfitters operates prominent flagship retail locations in Denver, Colorado.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is specific and self-contained. The source text, under the "Operations and Reach" section, explicitly states that Blue Ridge Outfitters "operates prominent flagship retail locations in key outdoor hubs: Denver, Colorado; Bend, Oregon; and Jackson, Wyoming." This directly supports the claim.',
#      rewritten_claim='Blue Ridge Outfitters operates prominent flagship retail locations in Bend, Oregon.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and clearly stated. The source text, under the "Operations and Reach" section, explicitly mentions that Blue Ridge Outfitters "operates prominent flagship retail locations in key outdoor hubs: Denver, Colorado; Bend, Oregon; and Jackson, Wyoming." This directly supports the claim.',
#      rewritten_claim='Blue Ridge Outfitters operates prominent flagship retail locations in Jackson, Wyoming.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly verifiable. The source text, under the "Operations and Reach" section, states: "This physical presence [of prominent flagship retail locations] allows customers to experience products firsthand and receive expert advice." This directly supports the claim.',
#      rewritten_claim="Blue Ridge Outfitters' prominent flagship retail locations allow customers to experience products firsthand.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is directly supported by the source text, specifically in the "Operations and Reach" section, which states, "This physical presence allows customers to experience products firsthand and receive expert advice." The claim is already self-contained and unambiguous.',
#      rewritten_claim="Blue Ridge Outfitters' prominent flagship retail locations allow customers to receive expert advice.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is a direct statement found in the "Products and Expertise" section of the source text. It is self-contained and clearly supported by the provided text.',
#      rewritten_claim='Blue Ridge Outfitters offers a wide selection of gear and apparel tailored to various outdoor pursuits.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is a direct statement found in the "Products and Expertise" section of the source text. The source text explicitly states, "The company specializes in equipment for hiking, camping, climbing, kayaking, and winter sports." The claim is already self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters specializes in equipment for hiking, camping, climbing, kayaking, and winter sports.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is clear and self-contained. The source text, under the "Products and Expertise" section, directly states: "Customers can find products from leading major outdoor brands alongside the company\'s own private label line...". This directly supports the claim.',
#      rewritten_claim='Customers can find products from leading major outdoor brands at Blue Ridge Outfitters.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly verifiable from the source text. The "Products and Expertise" section explicitly states that Blue Ridge Outfitters has "its own private label line, known as \'Pathfinder Gear\'".',
#      rewritten_claim="Blue Ridge Outfitters has its own private label line known as 'Pathfinder Gear'.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly verifiable from the source text. The "Products and Expertise" section explicitly states that Blue Ridge Outfitters\' private label line, \'Pathfinder Gear\', offers "quality alternatives."',
#      rewritten_claim="Blue Ridge Outfitters' private label line, known as 'Pathfinder Gear', offers quality alternatives to products from leading major outdoor brands.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and unambiguous. The source text, under the "Guided Adventures" section, explicitly states: "Beyond retail, Blue Ridge Outfitters embraces the spirit of exploration by offering guided adventure travel services." This directly supports the claim.',
#      rewritten_claim='Blue Ridge Outfitters offers guided adventure travel services.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly verifiable. The source text, under the "Guided Adventures" section, states: "These curated experiences cater to different levels of adventure, ranging from accessible local day hikes to challenging international trekking expeditions...". This directly supports the claim.',
#      rewritten_claim="Blue Ridge Outfitters' guided adventure travel services cater to different levels of adventure, including accessible local day hikes and challenging international trekking expeditions.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly supported by the source text. The "Guided Adventures" section explicitly states that Blue Ridge Outfitters offers "guided adventure travel services" and that "These curated experiences cater to different levels of adventure, ranging from accessible local day hikes to challenging international trekking expeditions".',
#      rewritten_claim="Blue Ridge Outfitters' guided adventure travel services range from accessible local day hikes to challenging international trekking expeditions.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is clearly stated and directly supported by the "Guided Adventures" section of the source text, which explicitly mentions that Blue Ridge Outfitters offers "guided adventure travel services" that allow customers to "fully immerse themselves in the outdoors under expert guidance." The claim is self-contained and does not require rewriting.',
#      rewritten_claim="Blue Ridge Outfitters' guided adventure travel services allow customers to experience the outdoors under expert guidance.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is a direct statement found in the "Values, Competition, and Future Vision" section of the source text. The claim is already self-contained and unambiguous.',
#      rewritten_claim='Commitment to the environment is a core value for Blue Ridge Outfitters.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly supported by the source text. The section "Values, Competition, and Future Vision" explicitly states: "The company actively practices environmental stewardship by donating a percentage of its profits to support conservation efforts".',
#      rewritten_claim='Blue Ridge Outfitters actively practices environmental stewardship by donating a percentage of its profits to support conservation efforts.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The original claim is self-contained and accurately reflects a statement made in the source text. The source text explicitly states that Blue Ridge Outfitters donates "a percentage of its profits to support conservation efforts, ensuring the preservation of the wild places its customers explore." The claim uses this exact phrasing and assertion. Therefore, no significant rewrite is needed, and the claim is directly supported.',
#      rewritten_claim="Blue Ridge Outfitters' practice of donating a percentage of its profits to support conservation efforts ensures the preservation of the wild places its customers explore.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is directly and explicitly stated in the source text within the "Values, Competition, and Future Vision" section. No rewrite is necessary as the claim is already self-contained and unambiguous.',
#      rewritten_claim="Blue Ridge Outfitters contends with major national retailers like REI and Dick's Sporting Goods.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly verifiable from the source text. The "Values, Competition, and Future Vision" section explicitly states that "It also competes with specialized local outfitters in its store locations".',
#      rewritten_claim='Blue Ridge Outfitters competes with specialized local outfitters in its store locations.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The source text, in the section "Values, Competition, and Future Vision," explicitly states: "It also competes with specialized local outfitters in its store locations and various online brands." This directly supports the claim. The claim is already self-contained and clear.',
#      rewritten_claim='Blue Ridge Outfitters competes with various online brands.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is a direct statement found in the "Values, Competition, and Future Vision" section of the source text. The source explicitly states, "Looking ahead, Blue Ridge Outfitters has ambitious plans to deepen its connection with the natural world by developing a network of branded eco-lodges situated near national parks..." The claim is already self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters plans to develop a network of branded eco-lodges situated near national parks.',
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and directly supported by the source text. The section "Values, Competition, and Future Vision" explicitly states, "Looking ahead, Blue Ridge Outfitters has ambitious plans to deepen its connection with the natural world by developing a network of branded eco-lodges...". This aligns perfectly with the claim.',
#      rewritten_claim="Blue Ridge Outfitters' plan to develop a network of branded eco-lodges is intended to deepen the company's connection with the natural world.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The claim is self-contained and unambiguous. The source text, in the "Values, Competition, and Future Vision" section, directly states: "Looking ahead, Blue Ridge Outfitters has ambitious plans to deepen its connection with the natural world by developing a network of branded eco-lodges situated near national parks, further enhancing the adventure experience for its clientele." This sentence explicitly supports the claim that the purpose of the eco-lodges is to enhance the adventure experience.',
#      rewritten_claim="Blue Ridge Outfitters' plan to develop a network of branded eco-lodges is intended to further enhance the adventure experience for its clientele.",
#      is_supported=True
#  ),
#  Prediction(
#      reasoning='The source text explicitly states, "For over half a century, Blue Ridge Outfitters has been equipping outdoor enthusiasts for their journeys. Founded more than 50 years ago..." This directly contradicts the claim that the company was founded less than 10 years ago. The claim is already self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters was founded less than 10 years ago.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The claim is contradicted by the source text. The text explicitly states that Blue Ridge Outfitters was "Founded more than 50 years ago by the avid mountaineer Jedediah \'Jed\' Stone". The claim asserts the opposite, that he had no interest in mountaineering. The claim is already self-contained and unambiguous.',
#      rewritten_claim="Jedediah 'Jed' Stone, the founder of Blue Ridge Outfitters, had no interest in mountaineering.",
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states that Blue Ridge Outfitters is "Headquartered in the vibrant city of Asheville, North Carolina." The claim asserts that the headquarters is in "a small village far from any city." This is a direct contradiction to the information provided in the source text. The original claim is self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters is headquartered in a small village far from any city.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states in the first paragraph that "Blue Ridge Outfitters continues its legacy as a family-owned business". This directly contradicts the part of the claim which asserts that Blue Ridge Outfitters is "not a family-owned business." Since one component of the compound claim is contradicted by the source text, the entire claim is contradicted. The original claim is already self-contained and unambiguous, so no significant rewrite is needed beyond ensuring the logical structure is clear.',
#      rewritten_claim='Blue Ridge Outfitters is a publicly-traded corporation and is not a family-owned business.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text states that Blue Ridge Outfitters was "Founded more than 50 years ago by the avid mountaineer Jedediah \'Jed\' Stone" and is "currently steered by the grandchildren of its founder." This directly contradicts the claim that Jedediah Stone still personally manages the company\'s daily operations. The claim is already self-contained.',
#      rewritten_claim="Jedediah 'Jed' Stone, the founder of Blue Ridge Outfitters, still personally manages the company's daily operations.",
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states that Blue Ridge Outfitters is "Headquartered in the vibrant city of Asheville, North Carolina." The claim asserts that the company is "primarily based in Denver, Colorado." Denver is mentioned in the text as one of the locations for its flagship retail stores, not as its headquarters or primary base. Therefore, the claim is contradicted by the source. The original claim is already self-contained and unambiguous, so no significant rewrite was necessary.',
#      rewritten_claim='Blue Ridge Outfitters is primarily based in Denver, Colorado.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states under "Operations and Reach" that "In addition to a comprehensive online store catering to customers nationwide, the company operates prominent flagship retail locations". This directly contradicts the claim that Blue Ridge Outfitters operates exclusively through physical stores and lacks an online store for nationwide customers. The claim is self-contained and clear.',
#      rewritten_claim='Blue Ridge Outfitters operates exclusively through its physical retail stores and does not have an online store for nationwide customers.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states that Blue Ridge Outfitters\' "prominent flagship retail locations" are in "Denver, Colorado; Bend, Oregon; and Jackson, Wyoming." While Asheville, North Carolina is mentioned as the company\'s headquarters, it is not listed among the flagship retail locations. Seattle, Washington is not mentioned anywhere in the text. Therefore, the claim is contradicted by the provided information.',
#      rewritten_claim="Blue Ridge Outfitters' flagship retail locations are situated in Asheville, North Carolina, and Seattle, Washington.",
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text states that "Blue Ridge Outfitters offers a wide selection of gear and apparel tailored to various outdoor pursuits. The company specializes in equipment for hiking, camping, climbing, kayaking, and winter sports." This directly contradicts the claim that the selection is "very narrow and limited." The claim was already self-contained.',
#      rewritten_claim='Blue Ridge Outfitters offers a very narrow and limited selection of outdoor gear and apparel for pursuits such as hiking, camping, climbing, kayaking, and winter sports.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states under "Products and Expertise" that "Blue Ridge Outfitters offers a wide selection of gear and apparel tailored to various outdoor pursuits. The company specializes in equipment for hiking, camping, climbing, kayaking, and winter sports." This directly contradicts the claim that the company specializes primarily in team sports equipment. The claim is already self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters specializes primarily in equipment for team sports like soccer and basketball, and not in equipment for outdoor pursuits.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The original claim asserts two things: 1) Blue Ridge Outfitters exclusively sells products from major international brands, and 2) it does not have its own private label line. The source text, under "Products and Expertise," directly contradicts this by stating, "Customers can find products from leading major outdoor brands alongside the company\'s own private label line, known as \'Pathfinder Gear\'". Therefore, the claim is contradicted. The rewritten claim maintains the core assertion for clear verification.',
#      rewritten_claim='Blue Ridge Outfitters exclusively sells products from major outdoor brands and does not have its own private label line of products.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states that Blue Ridge Outfitters\' private label line is known as \'Pathfinder Gear\'. The claim asserts it is \'Summit Seekers Collection\', which is directly contradicted by the provided text. The claim was already quite specific, but "The company\'s" was changed to "Blue Ridge Outfitters\'" for full clarity.',
#      rewritten_claim="Blue Ridge Outfitters' own private label line is known as 'Summit Seekers Collection'.",
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text describes Pathfinder Gear as "offering quality alternatives." It does not state or imply that it is recognized as a "premium, high-cost brand." The claim\'s assertion about its premium and high-cost nature is not supported by the provided text.',
#      rewritten_claim='Pathfinder Gear, the private label line of Blue Ridge Outfitters, is recognized as a premium and high-cost brand.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text, under the "Products and Expertise" section, explicitly states that "The company specializes in equipment for hiking, camping, climbing, kayaking, and winter sports." This directly contradicts the claim that Blue Ridge Outfitters does not stock equipment for kayaking. The claim is already self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters does not stock any equipment related to water sports, including kayaking.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The claim asserts that Blue Ridge Outfitters exclusively focuses on retail and does not offer guided adventure travel services. The source text, under the "Guided Adventures" section, directly contradicts this by stating, "Beyond retail, Blue Ridge Outfitters embraces the spirit of exploration by offering guided adventure travel services."',
#      rewritten_claim='Blue Ridge Outfitters exclusively focuses on retail operations and does not provide any guided adventure travel services.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text, under the "Guided Adventures" section, states that Blue Ridge Outfitters\' curated experiences "cater to different levels of adventure, ranging from accessible local day hikes to challenging international trekking expeditions." This directly contradicts the claim that these experiences are solely for elite adventurers and do not cater to beginners, as "accessible local day hikes" would be suitable for beginners. The claim is already quite specific, so minimal rewriting is needed for clarity.',
#      rewritten_claim='The guided adventure experiences offered by Blue Ridge Outfitters are exclusively designed for elite, highly experienced adventurers and do not offer options suitable for beginners.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states under the "Guided Adventures" section that Blue Ridge Outfitters offers experiences "ranging from accessible local day hikes to challenging international trekking expeditions." This directly contradicts the claim that their guided adventures are restricted to local day hikes and do not include international trekking expeditions. The claim is self-contained and does not require rewriting.',
#      rewritten_claim="Blue Ridge Outfitters' guided adventures are restricted to local day hikes and do not include any international trekking expeditions.",
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text, in the "Guided Adventures" section, states that Blue Ridge Outfitters offers "guided adventure travel services" and that these experiences allow customers to "fully immerse themselves in the outdoors under expert guidance." This directly contradicts the claim that customers are expected to navigate entirely on their own without any expert guidance. The claim is already quite specific, so minimal rewriting is needed for clarity.',
#      rewritten_claim="Customers participating in Blue Ridge Outfitters' adventure travel services are expected to navigate and explore entirely on their own, as no expert guidance is provided by the company for these services.",
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states, "Commitment to the environment is a core value for Blue Ridge Outfitters." The claim directly negates this statement. Therefore, the claim is contradicted by the source text. The original claim is self-contained and unambiguous.',
#      rewritten_claim='Environmental commitment is not a core value for Blue Ridge Outfitters.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states that "Commitment to the environment is a core value for Blue Ridge Outfitters. The company actively practices environmental stewardship by donating a percentage of its profits to support conservation efforts...". This directly contradicts the claim. The claim is self-contained and does not require rewriting.',
#      rewritten_claim='Blue Ridge Outfitters does not actively practice environmental stewardship.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states under "Values, Competition, and Future Vision" that "The company actively practices environmental stewardship by donating a percentage of its profits to support conservation efforts". This directly contradicts the claim. The claim is already self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters does not donate any percentage of its profits to support conservation efforts.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text states, "The company actively practices environmental stewardship by donating a percentage of its profits to support conservation efforts, ensuring the preservation of the wild places its customers explore." This directly contradicts the claim. The claim is already self-contained and clear.',
#      rewritten_claim="Blue Ridge Outfitters' actions, such as donating a percentage of its profits to conservation efforts, do not ensure the preservation of the wild places its customers explore.",
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states that "In the competitive outdoor retail landscape, Blue Ridge Outfitters contends with major national retailers like REI and Dick\'s Sporting Goods." This directly contradicts the claim that Blue Ridge Outfitters operates in a market free from such competition. The claim is already self-contained and unambiguous.',
#      rewritten_claim="Blue Ridge Outfitters operates in a market free from competition by major national retailers like REI and Dick's Sporting Goods.",
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text explicitly states under "Values, Competition, and Future Vision" that "Looking ahead, Blue Ridge Outfitters has ambitious plans to deepen its connection with the natural world by developing a network of branded eco-lodges situated near national parks...". This directly contradicts the claim. The original claim is self-contained and clear.',
#      rewritten_claim='Blue Ridge Outfitters has no future plans to develop any branded eco-lodges.',
#      is_supported=False
#  ),
#  Prediction(
#      reasoning='The source text states that Blue Ridge Outfitters plans "to deepen its connection with the natural world by developing a network of branded eco-lodges situated near national parks". This directly contradicts the claim that the eco-lodges will be in urban centers, far from national parks. The claim is already self-contained and unambiguous.',
#      rewritten_claim='Blue Ridge Outfitters plans to situate its future network of branded eco-lodges in urban centers, far from any national parks.',
#      is_supported=False
#  )]
